# %%
# Import libraries
import glob
import pandas as pd

# %%
# Create a list of csv files list from a folder (called data)
path = './data'
csv_files = glob.glob(path + "/*.csv")

print(csv_files)
# Out:
# ['./data\\201901-citibike-tripdata2.csv', './data\\201902-citibike-tripdata2.csv']

# %%
# Read each CSV file into DataFrame
# This creates a list of dataframes
df_list = (pd.read_csv(file) for file in csv_files)

# Concatenate all DataFrames into a single DataFrame using pandas concat function
big_citibike_df   = pd.concat(df_list, ignore_index=True)

# %%
# view big_df containing all citibike transactions for 2019
big_citibike_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 1911026           979  2019-02-28 23:59:43.3860  2019-03-01 00:16:02.7620
# 1911027           779  2019-02-28 23:59:48.2220  2019-03-01 00:12:47.5150
# 1911028           699  2019-02-28 23:59:48.6480  2019-03-01 00:11:28.5880
# 1911029           284  2019-02-28 23:59:59.2640  2019-03-01 00:04:43.6880
# 1911030           279  2019-02-28 23:59:55.0050  2019-03-01 00:04:34.9450
#
#          start station id            start station name  \
# ...

# %%
# use pandas sample to sample a fraction of the big_citibike_df (20%)
small_citibike_df = big_citibike_df.sample(frac=.25)

small_citibike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477758 entries, 167805 to 262318
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             477758 non-null  int64
#  1   starttime                477758 non-null  object
#  2   stoptime                 477758 non-null  object
#  3   start station id         477753 non-null  float64
#  4   start station name       477753 non-null  object
#  5   start station latitude   477758 non-null  float64
#  6   start station longitude  477758 non-null  float64
#  7   end station id           477753 non-null  float64
#  8   end station name         477753 non-null  object
#  9   end station latitude     477758 non-null  float64
#  10  end station longitude    477758 non-null  float64
#  11  bikeid                   477758 non-null  int64
#  12  usertype                 477758 non-null  object
# ...

# %%
# save small_df to csv file
small_citibike_df.to_csv('./sample_data/citi_bike_2019_frac_25.csv', index=False)
